# %% [markdown]
# # Bivariate Exploratory Data Analysis
#
# In this notebook I will perform bivariate analysis to understand the relationship between features and the target variable

# %% [markdown]
# ## Setup and Data Loading

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency


import sys, os
sys.path.append(os.path.abspath(".."))
from src.eda_utils import (spearman_trend, nominal_vs_binary,
                           rolling_lineplot, binary_vs_binary,
                           continuous_vs_binary, zone_breakdown,
                           continuous_by_category,
                           categorical_vs_categorical)

pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %%
df = pd.read_parquet("../data/silver/data_to_bivar.parquet", engine='pyarrow')
df = df.sort_values(["date", "time"]).reset_index(drop=True)
df.head()
# Out:
#          date      time vehicle_type pickup_location      drop_location  \
# 0  2024-01-01  00:19:34         Bike     Udyog Vihar      Ambience Mall
# 1  2024-01-01  01:35:18      Go Mini   Basai Dhankot            Madipur
# 2  2024-01-01  01:37:50     Go Sedan     Tughlakabad    Greater Kailash
# 3  2024-01-01  01:48:03         Auto     Palam Vihar  Kherki Daula Toll
# 4  2024-01-01  01:49:56     Go Sedan     Narsinghpur         Pulbangash
#
#    avg_vtat  is_cancelled
# 0      10.8             0
# 1       8.5             0
# 2       7.4             1
# 3       5.6             1
# 4       6.2             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             150000 non-null  object
#  1   time             150000 non-null  object
#  2   vehicle_type     150000 non-null  category
#  3   pickup_location  150000 non-null  category
#  4   drop_location    150000 non-null  category
#  5   avg_vtat         139500 non-null  float32
#  6   is_cancelled     150000 non-null  int64
# dtypes: category(3), float32(1), int64(1), object(2)
# memory usage: 4.7+ MB

# %% [markdown]
# ## Temporal features
#
# Temporal features are not directly usable by models but they can contain powerful temporal patterns so let's see if we can discover seasonal effects, temporal drift, time-of-day effects, etc

# %% [markdown]
# ### date vs target
#
# Let's check if there are trends, seasonability or anomalies in cancellation rate over time

# %%
daily = df[["date", "is_cancelled"]].copy()

daily["date"] = pd.to_datetime(daily["date"])
daily = daily.groupby("date").agg(is_cancelled=("is_cancelled", "sum"), total=("is_cancelled", "count")).reset_index()

daily["cancel_rate"] = daily["is_cancelled"] / daily["total"]
daily["rolling_7d"] = daily["cancel_rate"].rolling(window=7, center=True).mean()
daily["rolling_30d"] = daily["cancel_rate"].rolling(window=30, center=True).mean()
daily["weekday"] = daily["date"].dt.dayofweek

daily.head()
# Out:
#         date  is_cancelled  total  cancel_rate  rolling_7d  rolling_30d  \
# 0 2024-01-01           142    414     0.342995         NaN          NaN
# 1 2024-01-02           131    389     0.336761         NaN          NaN
# 2 2024-01-03           115    384     0.299479         NaN          NaN
# 3 2024-01-04           133    414     0.321256    0.327605          NaN
# 4 2024-01-05           134    416     0.322115    0.319211          NaN
#
#    weekday
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4

# %%
rolling_lineplot(
    daily["date"], daily["cancel_rate"],
    ylabel="Cancellation Rate",
    title="Daily Cancellation Rate with 7-Day & 30-Day Rolling Averages (weekends shaded)",
    daily_label="Daily rate",
    weekdays=daily["weekday"],
)

# %%
daily["date_ordinal"] = daily["date"].map(pd.Timestamp.toordinal)

spearman_trend(daily["date_ordinal"], daily["cancel_rate"],
               x_label="date", y_label="daily cancellation rate")
# Out:
# Spearman correlation (date vs daily cancellation rate): ρ = 0.0018, p = 9.7299e-01
#   → No statistically significant monotonic trend (p ≥ 0.05)

# %% [markdown]
# date has no signal, you can see that neither daily cancellation nor the 7-day or the 30-day rolling average show visible drift. This makes me reconsider that train/test split criteria based on date is even necessary, we will see it later
#
# But wait, is the rate flat because both cancelations and total rides are flat or because they are both trending in the same direction and the ratio hides it?

# %% [markdown]
# ### date vs total rides
#
# Does ride volume show any trends, seasonal patterns, or anomalies over time? Why total rides is even important? This analysis is a sanity check because I want to confirm that I'm working with a stable and representative sample that does not contain potential data dumps, outages, system failures, etc

# %%
rolling_lineplot(
    daily["date"], daily["total"],
    ylabel="Daily Rides",
    title="Daily Ride Volume Over Time (7-Day & 30-Day Rolling Averages)",
    daily_label="Total rides",
    mean_label_fmt="Mean volume ({mean:,.0f})",
    weekdays=daily["weekday"]
)

# %%
spearman_trend(daily["date_ordinal"], daily["total"],
               x_label="date", y_label="daily ride volume")
# Out:
# Spearman correlation (date vs daily ride volume): ρ = -0.0503, p = 3.3778e-01
#   → No statistically significant monotonic trend (p ≥ 0.05)

# %% [markdown]
# Ride volume is also stationary, no seasonal ramp-up or drop-off. Again the 7-day & 30-day rolling averages stay flat around the mean. Weekends show no signal either...
#
# Proving it strenghtens my doubts about the need of a time-based train/test split. A random split would work too.

# %% [markdown]
# ### date-related new features analysis
#
# All these features are cyclical ordinal because the last category comes before the first category again, but I will treat them as nominal and use chi-square

# %%
df_date = df[["date", "is_cancelled"]].copy()

df_date["date"] = pd.to_datetime(df_date["date"])

df_date["weekday"] = df_date["date"].dt.dayofweek       
df_date["month"] = df_date["date"].dt.month
df_date["day_of_month"] = df_date["date"].dt.day
df_date["week_of_year"] = df_date["date"].dt.isocalendar().week.astype(int)
df_date["quarter"] = df_date["date"].dt.quarter
df_date.head()
# Out:
#         date  is_cancelled  weekday  month  day_of_month  week_of_year  \
# 0 2024-01-01             0        0      1             1             1
# 1 2024-01-01             0        0      1             1             1
# 2 2024-01-01             1        0      1             1             1
# 3 2024-01-01             1        0      1             1             1
# 4 2024-01-01             1        0      1             1             1
#
#    quarter
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# ### weekday vs. target

# %%
day_labels = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]

wd_results = nominal_vs_binary(
    df_date, feature_col="weekday", target_col="is_cancelled",
    labels=day_labels, feature_label="Day of Week",
    figsize=(12, 8)
)
# Out:
# Chi-square: χ² = 5.28, dof = 6, p = 5.0802e-01
# Cramér's V = 0.0059
#
# No category stands out.
#
# All standardized residuals:
#      Cancelled
# Mon   1.140549
# Tue   0.518280
# Wed  -0.026094
# Thu  -0.907831
# Fri   0.458749
# Sat  -0.968844
# Sun  -0.221876

# %% [markdown]
# Day of week doesn't matter at all...

# %% [markdown]
# ### month vs target

# %%
month_labels = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
                "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
present_months = sorted(df_date["month"].unique())
present_labels = [month_labels[m - 1] for m in present_months]

mo_results = nominal_vs_binary(
    df_date, feature_col="month", target_col="is_cancelled",
    labels=present_labels, feature_label="Month",
    figsize=(14, 8)
)
# Out:
# Chi-square: χ² = 9.06, dof = 11, p = 6.1654e-01
# Cramér's V = 0.0078
#
# No category stands out.
#
# All standardized residuals:
#      Cancelled
# Jan  -0.210748
# Feb   0.993218
# Mar  -0.502844
# Apr  -0.987205
# May   0.250841
# Jun  -0.567411
# Jul   0.637589
# Aug   1.218456
# Sep   0.697071
# Oct  -0.995184
# Nov  -0.334726
# Dec  -0.191663

# %% [markdown]
# Same conclusion as before...

# %% [markdown]
# ### day of month vs target
#
# Skipped because day of month has 31 categories with no plausible causal mechanism linking a calendar day to cancellation behaviour and both weekday and month already show zero association with the target so a finner temporal granularity cannot reveal signal either

# %% [markdown]
# ### week of year vs target

# %%
woy_labels = [str(w) for w in sorted(df_date["week_of_year"].unique())]

woy_results = nominal_vs_binary(
    df_date, feature_col="week_of_year", target_col="is_cancelled",
    labels=woy_labels, feature_label="Week of Year",
    figsize=(18, 8))
# Out:
# Chi-square: χ² = 72.39, dof = 51, p = 2.6052e-02
# Cramér's V = 0.0220
#
# Categories with |standardized residual| > 2:
#     Cancelled
# 6    2.319898
# 31   2.242193
# 36   2.241745
#
# All standardized residuals:
#     Cancelled
# 1    0.723234
# 2    0.043339
# 3   -0.344753
# 4   -0.561259
# 5   -1.212644
# 6    2.319898
# 7    0.054565
# 8    0.031530
# 9   -0.134440
# 10  -0.147230
# 11  -0.935971
# 12  -0.583212
# 13   1.297762
# 14  -0.560448
# 15  -1.304114
# 16   1.937644
# 17  -1.365959
# 18  -0.130818
# 19  -0.037832
# 20   0.728441
# 21  -0.212549
# 22  -0.377447
# 23   1.034328
# 24  -0.834228
# 25  -0.017261
# 26  -1.516074
# 27   0.104693
# 28  -1.222933
# 29   0.021200
# 30   1.292545
# 31   2.242193
# 32   0.157977
# 33   0.092962
# 34   1.255925
# 35  -0.446072
# 36   2.241745
# 37  -0.045050
# 38   1.175226
# 39  -1.459507
# 40  -1.055009
# 41   0.183629
# 42  -1.145141
# 43   0.212397
# 44  -0.984819
# 45  -0.322087
# 46  -1.261177
# 47   0.092555
# ...

# %% [markdown]
# The graph shows 4 weeks where the 95% Wilson CI sits above the mean, but the count deviation isn't extreme enough on week 15 to be flagged by the standardized residual. Cramér's V is near zero, confirming we're in noise territory.
#
# This is expected from a multiple comparisons standpoint because with 52 categories tested simultaneously we could expect ~2–3 false positives by chance alone even under perfect independence. Besides that, they are isolated spikes with no seasonal pattern, entirely consistent with that null expectation

# %% [markdown]
# ### quarter vs target
#
# Skipped because quarter is a coarser grouping of month and month shows no association with cancellation so it would only dilute information, never create new signal

# %% [markdown]
# ### time vs target

# %%
df_time = df[["time", "is_cancelled"]].copy()

df_time["time_parsed"] = pd.to_datetime(df_time["time"], format="%H:%M:%S")
df_time["hour"] = df_time["time_parsed"].dt.hour

minutely = (
    df_time.assign(minute_bucket=df_time["time_parsed"].dt.floor("min"))
      .groupby("minute_bucket")["is_cancelled"]
      .agg(["sum", "count"])
      .reset_index()
)
minutely.columns = ["minute_bucket", "is_cancelled", "total"]
minutely["cancel_rate"] = minutely["is_cancelled"] / minutely["total"]
minutely.head()
# Out:
#         minute_bucket  is_cancelled  total  cancel_rate
# 0 1900-01-01 00:00:00            10     25     0.400000
# 1 1900-01-01 00:01:00             4     21     0.190476
# 2 1900-01-01 00:02:00             5     23     0.217391
# 3 1900-01-01 00:03:00             6     22     0.272727
# 4 1900-01-01 00:04:00            13     29     0.448276

# %%
from matplotlib.dates import HourLocator, DateFormatter

rolling_lineplot(
    minutely["minute_bucket"], minutely["cancel_rate"],
    rolling_windows=(30, 60),
    ylabel="Cancellation Rate",
    xlabel="Time of Day",
    title="Minute-Level Cancellation Rate Over 24h (30-min & 60-min Rolling Averages)",
    daily_label="Per-minute rate",
    rolling_label_fmt="{win}-min rolling avg",
    shade_weekends=False,
    xaxis_locator=HourLocator(interval=2),
    xaxis_formatter=DateFormatter("%H:%M"),
)

# %%
minutely["minute_ordinal"] = range(len(minutely))
spearman_trend(minutely["minute_ordinal"], minutely["cancel_rate"],
               x_label="time of day (minute)", y_label="cancellation rate")
# Out:
# Spearman correlation (time of day (minute) vs cancellation rate): ρ = -0.0123, p = 6.4067e-01
#   → No statistically significant monotonic trend (p ≥ 0.05)

# %% [markdown]
# Spearman shows nothing because the average cancellation rate is mostly flat across the 24h cycle, but there is something at the 22h–6h range, right? Well, that's likely a small-sample variance effect where each bucket has far fewer rides than during the day so the noise increases

# %% [markdown]
# ### time-related new features analysis
#
# All the features I have in mind are flags of the binary/categorical type. Let's check if there are clear patterns and how is the relationship with target

# %%
df_time["is_night"] = df_time["hour"].isin([*range(0, 6), *range(22, 24)]).astype(int)
df_time["is_business"] = df_time["hour"].isin(range(9, 18)).astype(int)
df_time["is_rush"] = df_time["hour"].isin([9, 10, 11, 15, 16, 17, 18, 19, 20, 21]).astype(int)
df_time.head()
# Out:
#        time  is_cancelled         time_parsed  hour  is_night  is_business  \
# 0  00:19:34             0 1900-01-01 00:19:34     0         1            0
# 1  01:35:18             0 1900-01-01 01:35:18     1         1            0
# 2  01:37:50             1 1900-01-01 01:37:50     1         1            0
# 3  01:48:03             1 1900-01-01 01:48:03     1         1            0
# 4  01:49:56             1 1900-01-01 01:49:56     1         1            0
#
#    is_rush
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# #### hour vs target

# %%
hour_labels = [f"{h:02d}" for h in range(24)]

hour_results = nominal_vs_binary(
    df_time, feature_col="hour", target_col="is_cancelled",
    labels=hour_labels,
    feature_label="Hour of Day",
    figsize=(18, 8)
)
# Out:
# Chi-square: χ² = 22.54, dof = 23, p = 4.8786e-01
# Cramér's V = 0.0123
#
# No category stands out.
#
# All standardized residuals:
#     Cancelled
# 00  -0.303422
# 01   0.901184
# 02  -1.182622
# 03   0.543801
# 04   0.208170
# 05   1.054312
# 06  -0.498827
# 07   0.598641
# 08  -0.096465
# 09   0.080263
# 10  -0.589604
# 11  -1.269901
# 12   0.424086
# 13   0.086047
# 14   1.055798
# 15   0.553568
# 16  -0.442357
# 17  -0.606916
# 18   1.110750
# 19   0.857101
# 20  -0.713357
# 21  -1.904122
# 22   0.835915
# 23  -0.129165

# %% [markdown]
# No hour shows a significant deviation from the overall rate. The only mild outlier is hour 21, slightly above-average volume with a marginally lower cancellation rate, possibly post-dinner return trips (typical Indian dinner falls between 20:30 and 22:00)

# %% [markdown]
# #### is_night vs target
#
# Night was defined as the range between 22h and 5:59h

# %%
night_results = binary_vs_binary(
    df_time, feature_col="is_night", target_col="is_cancelled",
    labels=("Not Night (6-21)", "Night (22-5)"),
    feature_label="Is Night",
)
# Out:
# Fisher's exact test:  p = 2.5823e-01
# Phi coefficient:      φ = +0.0029
#   → negligible positive association
#
# Odds ratio:           OR = 1.0196  95% CI [0.9860, 1.0543]
#   → CI contains 1 — no significant difference in odds

# %% [markdown]
# Both groups sit right on the overall mean with overlapping CI so riding at night doesn't change cancellation likelihood

# %% [markdown]
# #### is_business vs target
#
# Business hours were defined from 9h to 17:59h

# %%
business_results = binary_vs_binary(
    df_time, feature_col="is_business", target_col="is_cancelled",
    labels=("Non-Business Hours", "Business Hours (9-18)"),
    feature_label="Is Business Hours",
)
# Out:
# Fisher's exact test:  p = 5.6111e-01
# Phi coefficient:      φ = -0.0015
#   → negligible negative association
#
# Odds ratio:           OR = 0.9935  95% CI [0.9722, 1.0153]
#   → CI contains 1 — no significant difference in odds

# %% [markdown]
# Same story as night. Whether a ride is booked during working hours or not has no detectable effect on cancellation

# %% [markdown]
# #### is_rush vs target
#
# Rush hours were defined in the univariate analysis notebook as the ranges of 9h-10:59h and 15h-20:59h (rounded to 11h and 21h respectively)

# %%
rush_results = binary_vs_binary(
    df_time, feature_col="is_rush", target_col="is_cancelled",
    labels=("Non-Rush Hours", "Rush Hours (9-11, 15-21)"),
    feature_label="Is Rush Hour",
)
# Out:
# Fisher's exact test:  p = 1.0118e-01
# Phi coefficient:      φ = -0.0042
#   → negligible negative association
#
# Odds ratio:           OR = 0.9812  95% CI [0.9593, 1.0037]
#   → CI contains 1 — no significant difference in odds

# %% [markdown]
# Same again. Rush-hour rides cancel at the same rate as non-rush rides

# %% [markdown]
# ## Non-temporal features

# %% [markdown]
# ### vehicle_type vs target

# %%
vtype_order = sorted(df["vehicle_type"].unique())

vtype_results = nominal_vs_binary(
    df, feature_col="vehicle_type", target_col="is_cancelled",
    labels=vtype_order,
    feature_label="Vehicle Type",
)
# Out:
# Chi-square: χ² = 5.67, dof = 6, p = 4.6126e-01
# Cramér's V = 0.0061
#
# No category stands out.
#
# All standardized residuals:
#                Cancelled
# Auto            0.273426
# Bike           -0.594217
# Go Mini        -0.982160
# Go Sedan        1.479495
# Premier Sedan   0.006305
# Uber XL        -0.521578
# eBike          -0.038539

# %% [markdown]
# All seven vehicle types cluster tightly around the overall mean so vehicle_type carries no predictive signal for cancellation.
#
# From a business perspective, the ebike's cancellation rate  is higher compared to the regular bike, why? With urban mobility shifting towards bike-based transport, this gap can become an opportunity for the company to investigate the current ebike infrastructure and its pain points so Uber can invest in making this service more appealing to customers

# %% [markdown]
# ### avg_vtat vs vehicle_type

# %%
vtat_results = continuous_by_category(
    df,
    feature_col="avg_vtat",
    category_col="vehicle_type",
    feature_label="avg_vtat (minutes)",
    category_label="Vehicle Type",
    cache_path="imgs/avg_vtat_by_vehicle_type.png",
)
# Out:
# Rows with avg_vtat (minutes) present: 139,500 / 150,000 (10,500 dropped)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 vtat_results = continuous_by_category(
#       2     df,
#       3     feature_col="avg_vtat",
#       4     category_col="vehicle_type",
#       5     feature_label="avg_vtat (minutes)",
#       6     category_label="Vehicle Type",
#       7     cache_path="imgs/avg_vtat_by_vehicle_type.png",
#       8 )
#
# File ~/dscience/projects/uber-ride-cancellation-prediction/src/eda_utils/bivar_utils.py:556, in continuous_by_category(df, feature_col, category_col, feature_label, category_label, figsize, cache_path)
#     553 ss_tot = ((sub[feature_col] - sub[feature_col].mean()) ** 2).sum()
#     554 eta_sq = ss_bw / ss_tot
# --> 556 if cache_path and os.path.exists(cache_path):
#     557     img = plt.imread(cache_path)
# ...

# %% [markdown]
# All seven types have nearly identical mean and median VTAT, the distributions overlap almost entirely.
# The test again only picks something up because of the large sample

# %% [markdown]
# ### vehicle_type vs pickup_location

# %%
vp_results = categorical_vs_categorical(
    df,
    col_a="vehicle_type",
    col_b="pickup_location",
    col_a_label="Vehicle Type",
    col_b_label="Pickup Location",
    cache_prefix="imgs/vehicle_pickup",
)
# Out:
# Chi-square: χ² = 1050.37, dof = 1050, p = 4.9094e-01
# Cramér's V = 0.0342
#   → negligible association
# Cells with |std residual| > 2: 35 / 1232

# %% [markdown]
# Chi-square is non-significan and Cramér's V is negligible
# The row-normalised heatmap confirms that every vehicle type spreads across pickup locations in nearly identical proportions. A handful of cells exceed the residual threshold, but with so many cells that is well within chance expectation (around 5%). Knowing where a ride starts tells us nothing about which vehicle was booked

# %% [markdown]
# ### vehicle_type vs drop_location

# %%
vd_results = categorical_vs_categorical(
    df,
    col_a="vehicle_type",
    col_b="drop_location",
    col_a_label="Vehicle Type",
    col_b_label="Drop Location",
    cache_prefix="imgs/vehicle_drop",
)
# Out:
# Chi-square: χ² = 1101.08, dof = 1050, p = 1.3316e-01
# Cramér's V = 0.0350
#   → negligible association
# Cells with |std residual| > 2: 38 / 1232

# %% [markdown]
# Stat tests show same picture as pickup, basically nothing. The heatmaps show no systematic pairing either

# %% [markdown]
# ### pickup_location vs target

# %%
pickup_rate = (df.groupby("pickup_location", observed=True)["is_cancelled"].mean().sort_values())
pickup_sorted = pickup_rate.index.tolist()

pickup_results = nominal_vs_binary(
    df, feature_col="pickup_location", target_col="is_cancelled",
    labels=pickup_sorted,
    feature_label="Pickup Location (sorted by cancel rate)",
    figsize=(20, 8), tick_step=5, tick_fontsize=8,
    bar_width=0.9, show_vol_labels=False,
)
# Out:
# Chi-square: χ² = 203.70, dof = 175, p = 6.7753e-02
# Cramér's V = 0.0369
#
# Categories with |standardized residual| > 2:
#                          Cancelled
# RK Puram                  2.350879
# Jama Masjid               2.028570
# Gurgaon Railway Station  -2.091784
# Netaji Subhash Place      3.490184
#
# All standardized residuals:
#                            Cancelled
# Kanhaiya Nagar              0.305728
# Subhash Chowk              -0.576951
# RK Puram                    2.350879
# Welcome                    -0.679667
# Yamuna Bank                -0.414970
# IMT Manesar                 0.004906
# Okhla                      -0.995253
# South Extension             1.229837
# Peeragarhi                 -0.825255
# Kashmere Gate              -0.045113
# Subhash Nagar               0.437704
# Delhi Gate                  0.875021
# Azadpur                    -1.156512
# Sohna Road                 -0.100190
# Ghitorni                    1.634452
# ...

# %% [markdown]
# A handful of locations cross the residual threshold, but with this many comparisons a few false positives are likely without correction (too many different categories are affecting it)
#
# I don't have enough domain knowledge to justify grouping before looking at the data and I don't want to fall into selection bias. I'll continue analysing the relationship between routes (pickup + drop locations vs the target) and if adequate, consider target encoding with regularisation when modelling

# %% [markdown]
# ### drop_location vs target

# %%
drop_rate = (df.groupby("drop_location", observed=True)["is_cancelled"].mean().sort_values())
drop_sorted = drop_rate.index.tolist()

drop_results = nominal_vs_binary(
    df, feature_col="drop_location", target_col="is_cancelled",
    labels=drop_sorted,
    feature_label="Drop Location (sorted by cancel rate)",
    figsize=(20, 8))
# Out:
# Chi-square: χ² = 201.57, dof = 175, p = 8.2376e-02
# Cramér's V = 0.0367
#
# Categories with |standardized residual| > 2:
#                   Cancelled
# Ashram            -2.067658
# Rithala            2.972751
# Botanical Garden  -2.007621
# RK Puram           2.769041
#
# All standardized residuals:
#                            Cancelled
# Dwarka Mor                  1.333946
# Mayur Vihar                -1.118960
# Sultanpur                  -1.143166
# Noida Extension            -0.031793
# Sarojini Nagar              1.129026
# Lal Quila                  -0.497500
# Pulbangash                  1.314751
# Aya Nagar                  -0.799508
# Preet Vihar                 0.510880
# IGNOU Road                 -0.261785
# Panchsheel Park            -0.838984
# Vaishali                   -1.411826
# Jor Bagh                    0.197268
# Akshardham                 -0.904040
# Adarsh Nagar                1.436594
# Khan Market                 0.358569
# ...

# %% [markdown]
# Nearly identical picture to pickup location...

# %% [markdown]
# ### avg_vtat vs target

# %%
vtat_results = continuous_vs_binary(
    df, feature_col="avg_vtat", target_col="is_cancelled",
    feature_label="Avg. Vehicle Time at Arrival (min)",
)
# Out:
# Mann-Whitney U test:       U = 1,794,477,356,  p = 4.2200e-70
#   → Distributions differ significantly (p < 0.05)
#
# Point-biserial correlation: r = +0.0721,  p = 5.3630e-160
#   → negligible positive association
#
# Cohen's d:                 d = +0.1630
#   → negligible effect size
#
# Group means:  Not Cancelled = 8.291,  Cancelled = 8.905  (Δ = +0.613)

# %% [markdown]
# First feature with a statistically significant association with cancellation!
#
# But the summary stats are misleading. Cohen's d and KDE overlap suggest a weak effect because they assume a roughly monotonic relationship. The binned trend panel tells a different story: the relationship is highly non-linear and non-monotonic, let's zoom in

# %% [markdown]
# ### avg_vtat-related features analysis
#
# Let's break it into fine-grained 0.5-min buckets to see the true shape of the relationship

# %%
vtat_zones = [
    (2.0, 2.9, "Zero-cancel"),
    (3.0, 5.0, "Low"),
    (5.1, 11.9, "Baseline"),
    (12.0, 15.0, "Dip"),
    (15.1, 20.0, "Guaranteed-cancel"),
]

zone_breakdown(
    df, feature_col="avg_vtat", target_col="is_cancelled",
    zones=vtat_zones,
    feature_label="avg_vtat",
)
# Out:
# Zone summary:
#   Zero-cancel          [ 2.0 –  2.9]:  n =  7,693  rate = 0.0000
#   Low                  [ 3.0 –  5.0]:  n = 23,618  rate = 0.2634
#   Baseline             [ 5.1 – 11.9]:  n = 80,580  rate = 0.3165
#   Dip                  [12.0 – 15.0]:  n = 24,088  rate = 0.0937
#   Guaranteed-cancel    [15.1 – 20.0]:  n =  3,521  rate = 1.0000

# %% [markdown]
# Striking non-monotonic pattern with five distinct behavioural zones:
#
# - **Zero-cancel:** vehicle arrives almost instantly, nobody cancels.
# - **Low:** short waits still discourage cancellation, rate sits below the mean.
# - **Baseline:** bulk of the data, rate hovers around the overall mean.
# - **Dip:** unexpectedly the rate plunges despite a long wait. Could be a sunk-cost effect (riders who waited this long are committed) or some artefact of timeout mechanics.
# - **Guaranteed-cancel:** every single ride is cancelled. Almost certainly a system-level auto-cancellation timeout rather than rider choice.
#
# This non-linear structure means zone-based features can capture the real signal and avg_vtat is not a good fit for logistic regression, let's see the others

# %% [markdown]
# ### vtat_zone vs target

# %%
df["vtat_zone"] = pd.cut(
    df["avg_vtat"],
    bins=[0, 2.9, 5.0, 11.9, 15.0, 20.0],
    labels=["instant", "short", "normal", "dip", "timeout"],
    include_lowest=True,
)

df["is_instant_arrival"] = (df["avg_vtat"] <= 2.9).astype("Int8")
df["is_timeout"]         = (df["avg_vtat"] > 15.0).astype("Int8")
df["is_long_wait"]       = (df["avg_vtat"] > 11.9).astype("Int8")

print(f"DataFrame shape: {df.shape}\n")

print("vtat_zone value counts:")
print(df["vtat_zone"].value_counts(dropna=False).sort_index())
print(f"\nis_instant_arrival:  {df['is_instant_arrival'].sum()} ({df['is_instant_arrival'].mean():.1%})")
print(f"is_timeout:          {df['is_timeout'].sum()} ({df['is_timeout'].mean():.1%})")
print(f"is_long_wait:        {df['is_long_wait'].sum()} ({df['is_long_wait'].mean():.1%})")
# Out:
# DataFrame shape: (150000, 11)
#
# vtat_zone value counts:
# vtat_zone
# instant     6869
# short      24442
# normal     80580
# dip        24088
# timeout     3521
# NaN        10500
# Name: count, dtype: int64
#
# is_instant_arrival:  7693 (5.1%)
# is_timeout:          3521 (2.3%)
# is_long_wait:        27609 (18.4%)

# %% [markdown]
# #### vtat_zone vs target

# %%
zone_labels = ["instant", "short", "normal", "dip", "timeout"]
zone_results = nominal_vs_binary(
    df.dropna(subset=["vtat_zone"]),
    feature_col="vtat_zone", target_col="is_cancelled",
    labels=zone_labels,
    feature_label="VTAT Zone",
)
# Out:
# Chi-square: χ² = 16819.28, dof = 4, p = 0.0000e+00
# Cramér's V = 0.3472
#
# Categories with |standardized residual| > 2:
#          Cancelled
# instant -42.970983
# short    -4.310855
# normal   26.095722
# dip     -52.433433
# timeout  83.681691
#
# All standardized residuals:
#          Cancelled
# instant -42.970983
# short    -4.310855
# normal   26.095722
# dip     -52.433433
# timeout  83.681691

# %% [markdown]
# Easily the most powerful feature in the entire analysis. The instant and timeout zones are the extremes, but even the low and dip zones clearly separate from the baseline. The non-linear structure in avg_vtat is real and strong

# %% [markdown]
# #### is_instant_arrival vs target

# %%
instant_results = binary_vs_binary(
    df.dropna(subset=["avg_vtat"]),
    feature_col="is_instant_arrival", target_col="is_cancelled",
    labels=("Wait > 2.9 min", "Instant (≤ 2.9 min)"),
    feature_label="Is Instant Arrival",
)
# Out:
# Fisher's exact test:  p = 0.0000e+00
# Phi coefficient:      φ = -0.1465
#   → weak negative association
#
# Odds ratio:           OR = 0.0000  95% CI [nan, nan]
#   → Is Instant Arrival=1 decreases the odds of cancellation by 100.0%

# %% [markdown]
# A perfect one-sided predictor: when the vehicle arrives in under 3 minutes, cancellation is literally zero. OR collapses to 0 because there are no cancellations in that group. Phi understates the importance because it's dampened by the small proportion of rides in this bucket, but within it the signal is absolute. Useful as a hard rule rather than a probabilistic feature

# %% [markdown]
# #### is_timeout vs target

# %%
timeout_results = binary_vs_binary(
    df.dropna(subset=["avg_vtat"]),
    feature_col="is_timeout", target_col="is_cancelled",
    labels=("Wait ≤ 15 min", "Timeout (> 15 min)"),
    feature_label="Is Timeout",
)
# Out:
# Fisher's exact test:  p = 0.0000e+00
# Phi coefficient:      φ = +0.2654
#   → strong positive association
#
# Odds ratio:           OR = inf  95% CI [inf, inf]
#   → Is Timeout=1 increases the odds of cancellation by inf%

# %% [markdown]
# Mirror image of instant arrival: every ride above 15 minutes is cancelled, OR goes to infinity and phi is high. Almost certainly an automatic system timeout rather than a conscious rider decision. A small fraction of rides fall here but the prediction is deterministic. If confirmed as a system rule, it should be handled as a business rule rather than a model feature

# %% [markdown]
# #### is_long_wait vs target

# %%
long_results = binary_vs_binary(
    df.dropna(subset=["avg_vtat"]),
    feature_col="is_long_wait", target_col="is_cancelled",
    labels=("Wait ≤ 11.9 min", "Long wait (> 11.9 min)"),
    feature_label="Is Long Wait",
)
# Out:
# Fisher's exact test:  p = 1.2271e-142
# Phi coefficient:      φ = -0.0667
#   → weak negative association
#
# Odds ratio:           OR = 0.6687  95% CI [0.6478, 0.6903]
#   → Is Long Wait=1 decreases the odds of cancellation by 33.1%

# %% [markdown]
# Counter-intuitive at first: rides with a wait above 12 minutes actually cancel less. Phi is weak but highly significant. The explanation lies in zone composition, this bucket contains far more rides than the 15+ min timeout zone. So crossing the 12-minute mark means you're more likely in the committed-rider dip than in the auto-cancel zone. This feature captures a real behavioural pattern but it mixes two very different mechanisms, so vtat_zone is probably the cleaner choice for modelling

# %% [markdown]
# ### avg_vtat missingness analysis
#
# Let's see if there is some relationship between the NaNs and the target and also vehicle_type, why? because some vehicle types work differently in their booking system UI, for example you can estimate the shortest route with a GPS when you are using a car but what if the customer wants to

# %%
df["vtat_missing"] = df["avg_vtat"].isna().astype(int)

missing_results = binary_vs_binary(
    df, feature_col="vtat_missing", target_col="is_cancelled",
    labels=("VTAT Present", "VTAT Missing"),
    feature_label="avg_vtat Missing",
)
# Out:
# Fisher's exact test:  p = 0.0000e+00
# Phi coefficient:      φ = +0.3999
#   → strong positive association
#
# Odds ratio:           OR = inf  95% CI [inf, inf]
#   → avg_vtat Missing=1 increases the odds of cancellation by inf%

# %% [markdown]
# Probably the strongest finding so far. Every single ride with avg_vtat missing was cancelled, which makes sense if the ride was cancelled before the vehicle arrived so no VTAT was recorded. But the relationship is one-directional, not all cancellations have vtat_missing = 1.
#
# So we effectively have two populations of cancelled rides:
#
# 1. Cancelled before VTAT was recorded, no arrival time exists. These are "free" predictions, no model needed.
#
# 2. A vehicle arrived (VTAT exists) but the rider still cancelled, these are the hard cases for the model.
#
# The second group's cancellation rates will be analysed in the next notebook against every feature

# %%
df["date"] = pd.to_datetime(df["date"])
df["hour"] = pd.to_datetime(df["time"], format="%H:%M:%S").dt.hour
df["weekday"] = df["date"].dt.dayofweek
df["month"] = df["date"].dt.month
df["day_of_month"] = df["date"].dt.day
df["week_of_year"] = df["date"].dt.isocalendar().week.astype(int)
df["quarter"] = df["date"].dt.quarter
df["is_night"] = df["hour"].isin([*range(0, 6), *range(22, 24)]).astype(int)
df["is_business"] = df["hour"].isin(range(9, 18)).astype(int)
df["is_rush"] = df["hour"].isin([9, 10, 11, 15, 16, 17, 18, 19, 20, 21]).astype(int)

features_to_check = [
    "vehicle_type",
    "pickup_location",
    "drop_location",
    "hour",
    "weekday",
    "month",
    "day_of_month",
    "week_of_year",
    "quarter",
    "is_night",
    "is_business",
    "is_rush",
]

miss_summary = []
for col in features_to_check:
    grp = df.groupby(col, observed=True)["vtat_missing"].mean()
    miss_summary.append({
        "Feature": col,
        "Categories": grp.nunique(),
        "Miss Rate (min)": f"{grp.min():.2%}",
        "Miss Rate (max)": f"{grp.max():.2%}",
        "Spread (pp)": f"{(grp.max() - grp.min()) * 100:.1f}",
    })

miss_df = pd.DataFrame(miss_summary)
miss_df
# Out:
#             Feature  Categories Miss Rate (min) Miss Rate (max) Spread (pp)
# 0      vehicle_type           7           6.67%           7.22%         0.5
# 1   pickup_location         175           4.66%          10.29%         5.6
# 2     drop_location         169           5.19%           9.49%         4.3
# 3              hour          24           6.44%           8.09%         1.6
# 4           weekday           7           6.79%           7.21%         0.4
# 5             month          12           6.80%           7.41%         0.6
# 6      day_of_month          31           6.44%           7.74%         1.3
# 7      week_of_year          52           6.17%           7.94%         1.8
# 8           quarter           4           6.86%           7.26%         0.4
# 9          is_night           2           7.00%           7.03%         0.0
# 10      is_business           2           6.97%           7.03%         0.1
# ...

# %% [markdown]
# Missingness is spread almost perfectly evenly across every feature. Pickup and drop location have slightly larger spreads but with 176 categories some variation is expected by chance and no single location dominates

# %%
df.to_parquet("../data/silver/data_to_multivar.parquet", engine="pyarrow", index=False)
