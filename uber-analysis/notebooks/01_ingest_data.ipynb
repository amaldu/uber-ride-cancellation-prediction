# %% [markdown]
# # Import dependencies

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
import os
import pandas as pd
import glob

api = KaggleApi()
api.authenticate()

# %% [markdown]
# # View datasets

# %%
datasets = api.dataset_list(search='uber', page=1)
print("Found datasets containing 'uber':")
for i, ds in enumerate(datasets):
    print(f"{i+1}. {ds.ref} - {ds.title}")
# Out:
# Found datasets containing 'uber':
# 1. yashdevladdha/uber-ride-analytics-dashboard - Uber Data Analytics Dashboard
# 2. zusmani/uberdrives - My Uber Drives
# 3. yasserh/uber-fares-dataset - Uber Fares Dataset
# 4. varpit94/uber-stock-data - UBER Stock Data
# 5. ravi72munde/uber-lyft-cab-prices - Uber & Lyft Cab prices
# 6. fivethirtyeight/uber-pickups-in-new-york-city - Uber Pickups in New York City
# 7. bhanupratapbiswas/uber-data-analysis - Uber Data Analysis🚗 🚕
# 8. brllrb/uber-and-lyft-dataset-boston-ma - Uber and Lyft Dataset Boston, MA
# 9. ruchikakumbhar/uber-dataset - Uber Dataset
# 10. kanchana1990/uber-customer-reviews-dataset-2024 - Uber Customer Reviews Dataset (2024)
# 11. mhassansaboor/uber-stocks-dataset-2025 - Uber Stocks Dataset 2025
# 12. anupammajhi/uber-request-data - Uber Request Data.csv
# 13. kushsheth/uber-ride-price-prediction - UBER RIDE PRICE PREDICTION
# 14. ahmedshahriarsakib/uber-eats-usa-restaurants-menus - Uber Eats USA Restaurants and Menus 🍛 🍕🍔
# ...

# %% [markdown]
# # Import Dataset

# %%
dataset_ref = 'yashdevladdha/uber-ride-analytics-dashboard'
download_path = '../data/raw'

os.makedirs(download_path, exist_ok=True)
api.dataset_download_files(dataset_ref, path=download_path, unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/yashdevladdha/uber-ride-analytics-dashboard

# %% [markdown]
# # Load Dataset

# %%
csv_files = glob.glob(os.path.join(download_path, "*.csv"))
df = pd.read_csv(csv_files[0])
df
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Booking ID', 'Booking Status', 'Customer ID',
#        'Vehicle Type', 'Pickup Location', 'Drop Location', 'Avg VTAT',
#        'Avg CTAT', 'Cancelled Rides by Customer',
#        'Reason for cancelling by Customer', 'Cancelled Rides by Driver',
#        'Driver Cancellation Reason', 'Incomplete Rides',
#        'Incomplete Rides Reason', 'Booking Value', 'Ride Distance',
#        'Driver Ratings', 'Customer Rating', 'Payment Method'],
#       dtype='object')
