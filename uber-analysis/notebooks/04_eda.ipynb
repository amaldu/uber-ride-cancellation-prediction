# %%
import pandas as pd
import os
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load dataset

# %%
df_raw = pd.read_parquet("../data/bronze/train.parquet")
df_raw.head()
# Out:
#         date      time  booking_id customer_id   vehicle_type pickup_location  \
# 0 2024-01-01  07:26:17  CNR6813909  CID4108516           Auto        Ghitorni
# 1 2024-01-01  20:33:05  CNR6014687  CID6324135        Go Mini      India Gate
# 2 2024-01-01  18:47:45  CNR9542022  CID8537493       Go Sedan   Shastri Nagar
# 3 2024-01-01  21:09:18  CNR3451034  CID5482799  Premier Sedan    Shastri Park
# 4 2024-01-01  17:34:25  CNR3653334  CID7934159       Go Sedan      Karol Bagh
#
#      drop_location  avg_vtat   avg_ctat  cancelled_rides_by_customer  \
# 0  South Extension       7.7  43.400002                          NaN
# 1        Paharganj       3.5  38.400002                          NaN
# 2    Paschim Vihar       6.8        NaN                          NaN
# 3           Mundka       3.4        NaN                          NaN
# 4       Dwarka Mor       6.1  30.600000                          NaN
#
#   reason_for_cancelling_by_customer  cancelled_rides_by_driver  \
# ...

# %%
len(df_raw)
# Out:
# 112705

# %% [markdown]
# # Univariate Analysis
#
# ## date

# %%
df_raw.date.hist(figsize = (10,6))
# Out:
# <Axes: >

# %%
print(f" df_raw["date"].value_counts()")
# Out:
# date
# 2024-09-18    456
# 2024-05-09    456
# 2024-01-26    452
# 2024-02-06    452
# 2024-07-17    451
#              ...
# 2024-07-15    371
# 2024-08-12    370
# 2024-04-23    369
# 2024-05-02    357
# 2024-08-22    355
# Name: count, Length: 274, dtype: int64
